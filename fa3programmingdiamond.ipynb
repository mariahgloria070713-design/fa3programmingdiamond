# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahgloria070713-design/fa3programmingdiamond/blob/main/fa3programmingdiamond.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1

name = input("Enter Fullname: ")
age = input("Enter Age: ")
course = input("Enter course ")
print("")
print(f"Name: {name} ")
print(f"Age: {age}")
print(f"Course: {course}")

# %%
#fa3prog2

score = int(input("Enter Examination Score: "))
if score >= 75:
  print("PASSED")
else:
  print("FAILED")

# %%
#fa3prog3

name = input("Enter Student Name: ")
score = int(input("Enter Score: "))

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
else:
    print("F")
# Out:
# Enter Student Name: Mariah Gloria
# Enter Score: 99
# A
